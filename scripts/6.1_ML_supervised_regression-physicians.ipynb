# %% [markdown]
# # Supervised Machine Learning: Regression

# %% [markdown]
# ## Table of contents
#
# ### [1. Libraries and Data importations](#1)
# ### [2. Data Preparation](#2)
#
# -[ Data cleaning](#2.1)
#
# -[ Data Exploration](#2.2)
#
# ### [3. Hypothesis](#3)
# ### [4. Regression analysis](#4)
# -[ Variables reshaping](#4.1)
#
# -[ Spliting (training vs test)](#4.2)
#
# -[ Linear regression](#4.3)
# ### [5. Model performance](#5)
# -[ MSE & R2](#5.1)
#
# -[ Predicted vs real values](#5.2)
#
# -[ Comparing how the regression fits the training set](#5.3)
#
# ### [6. Conclusion](#6)

# %% [markdown]
# ## 1. Libraries and Data importations
# <div id='1'></div>

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

 

##to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Creating paths to the data folder of the project and to the folder for saving the charts
path_data = r'C:\Users\dacol\Documents\Data Project - careerfoundry\Europe health-deaths analysis\02 Data'
path_viz = r'C:\Users\dacol\Documents\Data Project - careerfoundry\Europe health-deaths analysis\04 Analysis\Visualizations'

# Importing the latest merged dataframe
df = pd.read_pickle(os.path.join(path_data,'Prepared Data','cod_merged_full.pkl'))

# %% [markdown]
# ## 2. Data Preparation
# <div id='2'></div>

# %% [markdown]
# ### Data cleaning
# <div id='2.1'></div>

# %%
df.shape
# Out:
# (45692, 114)

# %%
df.isnull().sum()
# Out:
# geo_code                                                       0
# country_region                                                 0
# year                                                           0
# sex                                                            0
# age                                                            0
#                                                            ...
# Too expensive                                              44203
# Too expensive or too far to travel or waiting list         44203
# Too far to travel                                          44203
# Waiting list                                               44203
# Wanted to wait and see if problem got better on its own    44203
# Length: 114, dtype: int64

# %% [markdown]
# All nulll values are either form mismatched scopes from the different datasets, or from unavailble data from Eurostat. The most important column being the aggregate of all causes of deaths, cleaning this column from null values is necessary.

# %%
df.dropna(subset=['A-R_V-Y: All causes of death (A00-Y89) excluding S00-T98'])
# Out:
#       geo_code                     country_region  year sex     age  \
# 0           AT                            Austria  2011   F   TOTAL
# 1           AT                            Austria  2011   F  Y_GE65
# 2           AT                            Austria  2011   F  Y_LT65
# 3           AT                            Austria  2011   M   TOTAL
# 4           AT                            Austria  2011   M  Y_GE65
# ...        ...                                ...   ...  ..     ...
# 48577     UKN0  Northern Ireland (UK) (NUTS 2021)  2018   M  Y_GE65
# 48578     UKN0  Northern Ireland (UK) (NUTS 2021)  2018   M  Y_LT65
# 48579     UKN0  Northern Ireland (UK) (NUTS 2021)  2018   T   TOTAL
# 48580     UKN0  Northern Ireland (UK) (NUTS 2021)  2018   T  Y_GE65
# 48581     UKN0  Northern Ireland (UK) (NUTS 2021)  2018   T  Y_LT65
#
#        A-R_V-Y: All causes of death (A00-Y89) excluding S00-T98  \
# 0                                                 920.47
# 1                                                4051.37
# 2                                                 131.62
# 3                                                 880.37
# 4                                                4402.11
# ...                                                  ...
# 48577                                            4308.63
# 48578                                             213.73
# 48579                                             834.56
# 48580                                            4202.75
# 48581                                             177.76
#
#        A15-A19_B90: Tuberculosis  ACC: Accidents (V01-X59, Y85, Y86)  \
# 0                           0.46                               24.45
# 1                           1.96                              101.39
# 2                           0.09                                5.06
# 3                           0.83                               35.93
# 4                           4.03                              125.77
# ...                          ...                                 ...
# 48577                       3.61                              113.50
# 48578                       0.00                               21.03
# 48579                       0.32                               30.65
# 48580                       1.96                              116.62
# 48581                       0.00                               13.89
#
#        ACC_OTH: Other accidents (W20-W64, W75-X39, X50-X59, Y86)  \
# 0                                                  11.02
# 1                                                  51.15
# 2                                                   0.90
# 3                                                  12.84
# 4                                                  53.46
# ...                                                  ...
# 48577                                              26.03
# 48578                                               2.93
# 48579                                               5.06
# 48580                                              20.91
# 48581                                               1.98
#
#        A_B: Certain infectious and parasitic diseases (A00-B99)  ...  \
# 0                                                   8.27         ...
# 1                                                  34.18         ...
# 2                                                   1.75         ...
# 3                                                   7.88         ...
# 4                                                  32.37         ...
# ...                                                  ...         ...
# 48577                                              53.50         ...
# 48578                                               1.66         ...
# 48579                                               9.81         ...
# 48580                                              50.63         ...
# 48581                                               1.85         ...
#
#        Didn't know any good doctor or specialist  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 48577                                        NaN
# 48578                                        NaN
# 48579                                        NaN
# 48580                                        NaN
# 48581                                        NaN
#
#        Fear of doctor, hospital, examination or treatment  No time  \
# 0                                                    NaN       NaN
# 1                                                    NaN       NaN
# 2                                                    NaN       NaN
# 3                                                    NaN       NaN
# 4                                                    NaN       NaN
# ...                                                  ...       ...
# 48577                                                NaN       NaN
# 48578                                                NaN       NaN
# 48579                                                NaN       NaN
# 48580                                                NaN       NaN
# 48581                                                NaN       NaN
#
#        No unmet needs to declare  Other reason  Too expensive  \
# 0                            NaN           NaN            NaN
# 1                            NaN           NaN            NaN
# 2                            NaN           NaN            NaN
# 3                            NaN           NaN            NaN
# 4                            NaN           NaN            NaN
# ...                          ...           ...            ...
# 48577                        NaN           NaN            NaN
# 48578                        NaN           NaN            NaN
# 48579                        NaN           NaN            NaN
# 48580                        NaN           NaN            NaN
# 48581                        NaN           NaN            NaN
#
#        Too expensive or too far to travel or waiting list  Too far to travel  \
# 0                                                    NaN                 NaN
# 1                                                    NaN                 NaN
# 2                                                    NaN                 NaN
# 3                                                    NaN                 NaN
# 4                                                    NaN                 NaN
# ...                                                  ...                 ...
# 48577                                                NaN                 NaN
# 48578                                                NaN                 NaN
# 48579                                                NaN                 NaN
# 48580                                                NaN                 NaN
# 48581                                                NaN                 NaN
#
#        Waiting list  Wanted to wait and see if problem got better on its own
# 0               NaN                                                NaN
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3               NaN                                                NaN
# 4               NaN                                                NaN
# ...             ...                                                ...
# 48577           NaN                                                NaN
# 48578           NaN                                                NaN
# 48579           NaN                                                NaN
# 48580           NaN                                                NaN
# 48581           NaN                                                NaN
#
# [45540 rows x 114 columns]

# %%
dups = df.duplicated()
dups.shape # no duplicates found
# Out:
# (45692,)

# %% [markdown]
# ### Data Exploration
# <div id='2.2'></div>

# %%
pd.set_option('display.max_rows', None)
df.count()
# Out:
# geo_code                                                                                                        45692
# country_region                                                                                                  45692
# year                                                                                                            45692
# sex                                                                                                             45692
# age                                                                                                             45692
# A-R_V-Y: All causes of death (A00-Y89) excluding S00-T98                                                        45540
# A15-A19_B90: Tuberculosis                                                                                       41193
# ACC: Accidents (V01-X59, Y85, Y86)                                                                              45534
# ACC_OTH: Other accidents (W20-W64, W75-X39, X50-X59, Y86)                                                       45393
# A_B: Certain infectious and parasitic diseases (A00-B99)                                                        45492
# A_B_OTH: Other infectious and parasitic diseases (remainder of A00-B99)                                         45435
# B15-B19_B942: Viral hepatitis and sequelae of viral hepatitis                                                   41859
# B180-B182: Chronic viral hepatitis B and C                                                                      23865
# B20-B24: Human immunodeficiency virus [HIV] disease                                                             35868
# C00-C14: Malignant neoplasm of lip, oral cavity, pharynx                                                        45183
# C00-D48: Neoplasms                                                                                              45540
# C15: Malignant neoplasm of oesophagus                                                                           45024
# C16: Malignant neoplasm of stomach                                                                              45375
# C18-C21: Malignant neoplasm of colon, rectosigmoid junction, rectum, anus and anal canal                        45525
# C22: Malignant neoplasm of liver and intrahepatic bile ducts                                                    45435
# C25: Malignant neoplasm of pancreas                                                                             45510
# C32: Malignant neoplasm of larynx                                                                               43587
# C33_C34: Malignant neoplasm of trachea, bronchus and lung                                                       45540
# C43: Malignant melanoma of skin                                                                                 45027
# C50: Malignant neoplasm of breast                                                                               43554
# C53: Malignant neoplasm of cervix uteri                                                                         30633
# C54_C55: Malignant neoplasm of other parts of uterus                                                            30801
# C56: Malignant neoplasm of ovary                                                                                30879
# C61: Malignant neoplasm of prostate                                                                             30933
# C64: Malignant neoplasm of kidney, except renal pelvis                                                          45177
# C67: Malignant neoplasm of bladder                                                                              45330
# C70-C72: Malignant neoplasm of brain and central nervous system                                                 45393
# C73: Malignant neoplasm of thyroid gland                                                                        43593
# C81-C86: Hodgkin disease and lymphomas                                                                          45378
# C88_C90_C96: Other malignant neoplasm of lymphoid, haematopoietic and related tissue                            45288
# C91-C95: Leukaemia                                                                                              45390
# C: Malignant neoplasms (C00-C97)                                                                                45540
# C_OTH: Other malignant neoplasms (remainder of C00-C97)                                                         45531
# D00-D48: Non-malignant neoplasms (benign and uncertain)                                                         45246
# D50-D89: Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism    45171
# E10-E14: Diabetes mellitus                                                                                      45423
# E: Endocrine, nutritional and metabolic diseases (E00-E90)                                                      45504
# E_OTH: Other endocrine, nutritional and metabolic diseases (remainder of E00-E90)                               45285
# F01_F03: Dementia                                                                                               42795
# F10: Mental and behavioural disorders due to use of alcohol                                                     40971
# F: Mental and behavioural disorders (F00-F99)                                                                   45450
# F_OTH: Other mental and behavioural disorders (remainder of F00-F99)                                            43323
# G20: Parkinson disease                                                                                          45336
# G30: Alzheimer disease                                                                                          45381
# G_H: Diseases of the nervous system and the sense organs (G00-H95)                                              45534
# G_H_OTH: Other diseases of the nervous system and the sense organs (remainder of G00-H95)                       45522
# I20-I25: Ischaemic heart diseases                                                                               45540
# I20_I23-I25: Other ischaemic heart diseases                                                                     45534
# I21_I22: Acute myocardial infarction including subsequent myocardial infarction                                 45477
# I30-I51: Other heart diseases                                                                                   45540
# I60-I69: Cerebrovascular diseases                                                                               45531
# I: Diseases of the circulatory system (I00-I99)                                                                 45540
# I_OTH: Other diseases of the circulatory system (remainder of I00-I99)                                          45540
# J09-J11: Influenza (including swine flu)                                                                        39312
# J12-J18: Pneumonia                                                                                              45468
# J40-J44_J47: Other lower respiratory diseases                                                                   45540
# J40-J47: Chronic lower respiratory diseases                                                                     45540
# J45_J46: Asthma and status asthmaticus                                                                          43770
# J: Diseases of the respiratory system (J00-J99)                                                                 45540
# J_OTH: Other diseases of the respiratory system (remainder of J00-J99)                                          45468
# K25-K28: Ulcer of stomach, duodenum and jejunum                                                                 44739
# K70_K73_K74: Chronic liver disease                                                                              45420
# K72-K75: Chronic liver disease (excluding alcoholic and toxic liver disease)                                    26616
# K: Diseases of the digestive system (K00-K93)                                                                   45540
# K_OTH: Other diseases of the digestive system (remainder of K00-K93)                                            45495
# L: Diseases of the skin and subcutaneous tissue (L00-L99)                                                       43797
# M: Diseases of the musculoskeletal system and connective tissue (M00-M99)                                       45156
# M_OTH: Other diseases of the musculoskeletal system and connective tissue (remainder of M00-M99)                44982
# N00-N29: Diseases of kidney and ureter                                                                          45468
# N: Diseases of the genitourinary system (N00-N99)                                                               45501
# N_OTH: Other diseases of the genitourinary system (remainder of N00-N99)                                        44958
# O: Pregnancy, childbirth and the puerperium (O00-O99)                                                           18297
# P: Certain conditions originating in the perinatal period (P00-P96)                                             44856
# Q: Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99)                               45108
# R95: Sudden infant death syndrome                                                                               31137
# R96-R99: Ill-defined and unknown causes of mortality                                                            44532
# R: Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified (R00-R99)            45489
# RHEUM_ARTHRO: Rheumatoid arthritis and arthrosis (M05-M06,M15-M19)                                              41802
# R_OTH: Other symptoms, signs and abnormal clinical and laboratory findings (remainder of R00-R99)               43752
# TOXICO: Drug dependence, toxicomania (F11-F16, F18-F19)                                                         29361
# U071: COVID-19, virus identified                                                                                 7722
# U072: COVID-19, virus not identified                                                                             6204
# U_COV19_OTH: COVID-19, other                                                                                     2703
# V01-Y89: External causes of morbidity and mortality (V01-Y89)                                                   45537
# V01-Y89_OTH: Other external causes of morbidity and mortality (remainder of V01-Y89)                            40863
# V_Y85: Transport accidents (V01-V99, Y85)                                                                       45297
# W00-W19: Falls                                                                                                  45390
# W65-W74: Accidental drowning and submersion                                                                     42735
# X40-X49: Accidental poisoning by and exposure to noxious substances                                             43716
# X60-X84_Y870: Intentional self-harm                                                                             45342
# X85-Y09_Y871: Assault                                                                                           41415
# Y10-Y34_Y872: Event of undetermined intent                                                                      36270
# inhabitants_per_physician                                                                                        2857
# total_physicians                                                                                                 2964
# physicians_per_100K_inhabitants                                                                                  2857
# euros_per_inhabitant                                                                                              347
# inhabitants_per_bed                                                                                              2629
# total_beds                                                                                                       2736
# beds_per_100K_inhabitants                                                                                        2629
# Didn't know any good doctor or specialist                                                                        1489
# Fear of doctor, hospital, examination or treatment                                                               1489
# No time                                                                                                          1489
# No unmet needs to declare                                                                                        1489
# Other reason                                                                                                     1489
# Too expensive                                                                                                    1489
# Too expensive or too far to travel or waiting list                                                               1489
# Too far to travel                                                                                                1489
# Waiting list                                                                                                     1489
# Wanted to wait and see if problem got better on its own                                                          1489
# dtype: int64

# %% [markdown]
# Only columns with 5000 rows or more will be used for the regression analysis, meaning all added columns from different datasets other the causes of deaths won't be of use.

# %%
sns.displot(df['A-R_V-Y: All causes of death (A00-Y89) excluding S00-T98'], bins=25, kde =True) # showing extreme values from the main variable

# %% [markdown]
# Inside the different causes of deaths, the one about COVID could be of interest in order tjo see whether there is a link between the global number of deaths and the impact of covid.

# %%
#ploting in a scatter plot with all cause of deaths and covid:

sns.lmplot(x = 'A-R_V-Y: All causes of death (A00-Y89) excluding S00-T98', y='physicians_per_100K_inhabitants',data = df)
plt.title('All deaths in relation to the number of physicians')  
plt.xlabel('All causes of deaths')  
plt.ylabel('Number of physicians per 100k inhabitants')  
plt.show()

# %% [markdown]
# There seems to be a weak positive relation showing that the more physisicians there are, the more global deaths there are.

# %% [markdown]
# ## 3. Hypothesis
# <div id='3'></div>

# %% [markdown]
# Hypothesis about the impact of the number ofo physicians on global european deaths :
#
# **If there are more physicians, then there are more global deaths (all causes included)**

# %% [markdown]
# ## 4. Regression analysis
# <div id='4'></div>

# %% [markdown]
# ### Variables reshaping
# <div id='4.1'></div>

# %%
#creating a new subset and droping Nan values for the missing data on physicians per 100K inhabitants:

df_reg = df[['A-R_V-Y: All causes of death (A00-Y89) excluding S00-T98','physicians_per_100K_inhabitants']]
df_reg.isnull().sum()
# Out:
# A-R_V-Y: All causes of death (A00-Y89) excluding S00-T98      152
# physicians_per_100K_inhabitants                             42835
# dtype: int64

# %%
#droping all Nan values

df_reg = df_reg.dropna()
df_reg.shape # there are enough rows for a linear regression analysis !
# Out:
# (2834, 2)

# %%
# Reshaping both variables into NumPy arrays

X = df_reg['physicians_per_100K_inhabitants'].values.reshape(-1,1) # As the independent variable
y = df_reg['A-R_V-Y: All causes of death (A00-Y89) excluding S00-T98'].values.reshape(-1,1) # all causes of deaths being the dependent variable

# %%
X
# Out:
# array([[482.05],
#        [487.26],
#        [496.47],
#        ...,
#        [122.97],
#        [125.26],
#        [132.95]])

# %%
y
# Out:
# array([[900.93],
#        [932.1 ],
#        [927.5 ],
#        ...,
#        [298.94],
#        [384.29],
#        [374.28]])

# %% [markdown]
# ### Spliting (training vs test)
# <div id='4.2'></div>

# %%
# Spliting data into a training set and a test set (70% - 30%):

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# ### Linear regression
# <div id='4.3'></div>

# %%
# Creating a regression object

regression = LinearRegression()  #object that will fit onto the training data arrays

# %%
# Fitting the training set in the regeression object

regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting values of y using X

y_predicted = regression.predict(X_test)

# %%
# Creating a plot that shows the regression line from the model on the test set

plot_test = plt
plot_test.scatter(X_test, y_test, color='gray', s = 15)
plot_test.plot(X_test, y_predicted, color='red', linewidth =3)
plot_test.title('All causes of deaths vs number of physicians')
plot_test.xlabel('Number of physicians per 100k inhabitants')
plot_test.ylabel('Number of global deaths per 100k inhabitants')
plot_test.show()

# %% [markdown]
# ## 5. Model performance
# <div id='5'></div>

# %% [markdown]
# ### MSE & R2
# <div id='5.1'></div>

# %%
# Creating objects that contain the model summary statistics

rmse = mean_squared_error(y_test, y_predicted)
r2 = r2_score(y_test, y_predicted)

# %%
# Printing the model summary statistics in order to evaluate the performamnce of the model:

print('Slope:' ,regression.coef_)
print('Root mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [[0.58691731]]
# Root mean squared error:  72419.14970361807
# R2 score:  0.0795125209344083

# %% [markdown]
# - The positive slope of 0.6 shows the slightly positive relationship of both variables, both growing as one increases.
# - The average squared error of about 72k is significant, proof of a high distance from the points to the regression line: the accurancy of the  model isn't very high.
# - Its R-squared value is very low, close to 0, meaning the fit is not good.

# %% [markdown]
# ### Predicted vs real values
# <div id='5.2'></div>

# %%
y_predicted
# Out:
# array([[ 973.3017624 ],
#        [1175.5710742 ],
#        [1099.76483472],
#        [ 945.14733914],
#        [1022.3093576 ],
#        [ 916.12427826],
#        [1010.70013325],
#        [ 949.44357383],
#        [ 888.78567006],
#        [1011.83288366],
#        [1026.34734868],
#        [ 993.09848319],
#        [ 983.93083484],
#        [ 971.09495332],
#        [1054.78936142],
#        [1146.52453664],
#        [ 886.30887903],
#        [1176.25776745],
#        [ 936.00316748],
#        [ 937.26503969],
#        [ 994.3603554 ],
#        [1096.31376095],
#        [ 997.41819458],
#        [ 994.34861706],
#        [ 869.52304402],
#        [1017.55532741],
#        [ 945.80468652],
#        [1001.79072852],
#        [1046.72511761],
#        [1060.82287134],
#        [ 951.83819645],
#        [ 901.48069143],
#        [ 989.88217634],
#        [ 881.69570899],
#        [1057.44222765],
#        [ 988.52639736],
#        [ 985.15749201],
#        [1009.30913923],
#        [1119.27983521],
#        [ 926.01970407],
#        [1075.60731833],
#        [ 928.36150413],
#        [ 986.61304694],
#        [1028.00832466],
#        [ 905.4775983 ],
#        [1009.29740089],
#        [ 980.56779867],
#        [ 986.85368303],
#        [ 973.10221051],
#        [1040.16338211],
#        [ 997.18342765],
#        [1049.72426505],
#        [1015.94717398],
#        [ 998.41008483],
#        [ 865.76677325],
#        [1098.18015799],
#        [1054.84805315],
#        [1049.29581542],
#        [ 981.53621222],
#        [ 986.78912213],
#        [1048.80867405],
#        [ 915.88364217],
#        [ 979.76372196],
#        [ 944.4371692 ],
#        [ 947.69456025],
#        [1002.41286087],
#        [1032.60975635],
#        [1060.04227132],
#        [1006.8969091 ],
#        [1052.8525343 ],
#        [1009.60259789],
#        [ 945.08277823],
#        [1028.36047505],
#        [ 980.14521821],
#        [ 867.4570951 ],
#        [1052.96404859],
#        [ 935.83296146],
#        [1055.10042759],
#        [ 945.91033164],
#        [1072.98966714],
#        [1013.13584008],
#        [ 925.12172059],
#        [1002.18396312],
#        [ 973.41914586],
#        [1017.69618756],
#        [1017.49663568],
#        [1072.23841298],
#        [ 944.5897677 ],
#        [1021.46419668],
#        [ 873.99535391],
#        [ 999.31393748],
#        [1015.89435143],
#        [ 997.58840059],
#        [1130.51343248],
#        [1060.60571194],
#        [1077.88455748],
#        [ 998.16357956],
#        [1060.45898261],
#        [ 945.01821733],
#        [1015.91782812],
#        [ 951.46256937],
#        [ 933.18009523],
#        [ 984.44732207],
#        [1025.43175768],
#        [ 914.29896544],
#        [1010.89968514],
#        [ 888.83849262],
#        [ 934.94671633],
#        [1020.33731545],
#        [ 957.46086426],
#        [ 935.4749419 ],
#        [1023.79425839],
#        [1047.89308305],
#        [1010.54753475],
#        [1005.12441883],
#        [ 908.89345703],
#        [1046.63121084],
#        [ 983.97191905],
#        [ 997.18342765],
#        [1040.0342603 ],
#        [1070.27810917],
#        [1010.65904904],
#        [ 991.59010571],
#        [ 882.89888947],
#        [ 948.6218896 ],
#        [ 899.19171393],
#        [ 886.15628052],
#        [1073.61179948],
#        [1046.64294919],
#        [ 958.66404474],
#        [1009.40891518],
#        [ 891.15094681],
#        [1007.02016173],
#        [ 870.36233577],
#        [ 958.92228835],
#        [1049.57166655],
#        [ 983.59629198],
#        [ 888.35135126],
#        [1026.96361185],
#        [ 893.56904612],
#        [1191.31806557],
#        [1008.80439035],
#        [1004.96008198],
#        [1079.0583921 ],
#        [1005.35331658],
#        [1035.09241657],
#        [ 948.02323395],
#        [ 970.90127061],
#        [1003.27562931],
#        [1049.54232069],
#        [ 962.61986739],
#        [ 913.40098196],
#        [ 972.62093832],
#        [1092.60444356],
#        [1077.09221912],
#        [ 961.21713503],
#        [ 903.95748247],
#        [1033.64273082],
#        [1086.24812912],
#        [1256.28394238],
#        [ 971.85207665],
#        [ 930.68569667],
#        [1029.23498183],
#        [ 917.50940311],
#        [ 923.01468746],
#        [ 953.2878822 ],
#        [ 995.09400204],
#        [ 951.42148516],
#        [ 856.17067527],
#        [1041.47807688],
#        [ 993.25695086],
#        [1051.74326059],
#        [1000.74601571],
#        [ 958.96337256],
#        [1013.75210325],
#        [1055.31171782],
#        [ 941.49084431],
#        [1041.06723476],
#        [ 918.16088132],
#        [1067.98913167],
#        [ 854.6799053 ],
#        [1056.87878703],
#        [1051.26785757],
#        [ 923.06751002],
#        [1092.87442553],
#        [1019.06370489],
#        [ 964.29845089],
#        [1011.4748641 ],
#        [ 890.15318739],
#        [ 966.68133516],
#        [1020.29036206],
#        [1079.7568237 ],
#        [1082.76770948],
#        [1044.21311153],
#        [ 984.8112108 ]])

# %%
# Creating a dataframe comparing the actual and predicted values of y

data = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_predicted.flatten()})
data.head(20)
# Out:
#      Actual    Predicted
# 0    719.00   973.301762
# 1   1469.05  1175.571074
# 2    849.01  1099.764835
# 3    908.41   945.147339
# 4   1127.11  1022.309358
# 5   1278.81   916.124278
# 6   1415.42  1010.700133
# 7    983.87   949.443574
# 8    698.01   888.785670
# 9    742.18  1011.832884
# 10  1250.63  1026.347349
# 11  1022.88   993.098483
# 12   987.96   983.930835
# 13   786.38   971.094953
# 14   961.53   975.174029
# 15  1054.90  1011.791799
# 16   723.61   956.198992
# 17  1017.85   985.679848
# 18  1220.49   956.932639
# 19   737.74  1032.821047

# %% [markdown]
# ### Comparing how the regression fits the training set
# <div id='5.3'></div>

# %%
#Predicitng X_train
y_predicted_train = regression.predict(X_train)

# %%
rmse = mean_squared_error(y_train, y_predicted_train)
r2 = r2_score(y_train, y_predicted_train)

# %%
print('Slope:' ,regression.coef_)
print('Mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [[0.58691731]]
# Mean squared error:  80195.34650631883
# R2 score:  0.05955007778663579

# %% [markdown]
# Same comment applies on the training and the test sets, with a slightly better result than on the test set, meaning the model isn't that performant, nor overfitting.

# %%
# Visualizing the training set results

plot_test = plt
plot_test.scatter(X_train, y_train, color='green', s = 15)
plot_test.plot(X_train, y_predicted_train, color='red', linewidth =3)
plot_test.title('All causes of deaths vs number of physicians (Train set)')
plot_test.xlabel('Number of physicians per 100k inhabitants')
plot_test.ylabel('Number of global deaths per 100k inhabitants')
plot_test.show()

# %% [markdown]
# ## Conclusion
# <div id='6'></div>

# %% [markdown]
# The model isn't accurate enough to allow for a verified hypothesis : The higher the number of physicians per 100k inhabitants doesn't equte with more or less deaths (all causes included) in Europe.
#
# Unfortunatly, the lack of data on the other variables on healtcare ressources doesn't allow for other comparisons.
#
# The conclusion isn't very surprising, even though we could have thought before the study that a high number of physicians would diminish the number of deaths. The positive slight relation is surprising and thankfully being invalidated by this linear regression study.
